# %% [markdown]
# ![hacker_rank_set_union_intersection.png](attachment:hacker_rank_set_union_intersection.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
M = int(input())
a = list(map(int,input().split()))
N = int(input())
b = list(map(int,input().split()))

a_uni_b          = set(a).union(set(b))
intersection_a_b = set(a).intersection(set(b))
diff_a_b         = list(a_uni_b.difference(intersection_a_b))

# diff_a_b = diff_a_b.sort()
# print(diff_a_b.sort(reverse=False))

for i in diff_a_b.sort():
    print(i)
# Out:
# None
# 5
# 7
# 8
# 9
